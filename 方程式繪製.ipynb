# %%
import numpy as np
import matplotlib.pyplot as plt
pi=np.pi
def u(t):
    if t<0:
        return(0)
    else:
        return(1)
def e(t):
    return(np.exp(t))
def sin(t):
    return(np.sin(t))
def cos(t):
    return(np.cos(t))
def ten(t):
    return(np.tan(t))

# %%
l=3/1000
ts=np.linspace(0.001,l,1000)
ft=list()
c=list()
l=list()
v=list()
i=list()
for t in ts:
    # ft.append((t**2)*(u(t-0)-u(t-2))+(1-t-4*t**2)*u(t-2))
    ft.append(2*sin(2*pi*1000*t))
    c.append(1/(2*pi*t*0.001))
    l.append((2*pi*t*0.001))
    v.append(20*e(-t/0.043))
    i.append(20/43000*e(-t/0.043))

# %%
ft=list()
f=1000
t=2000
ts=np.linspace(1/t,5/t,1000)
for t in ts:
    # ft.append((t**2)*(u(t-0)-u(t-2))+(1-t-4*t**2)*u(t-2))
    ft.append(2*sin(2*pi*f*t))
plt.figure(figsize=(8,6))
plt.ylabel('v')
plt.xlabel('s')
plt.grid(True)
plt.plot(ts, ft, color='red')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.ylabel('X')
plt.xlabel('t')
plt.grid(True)
plt.plot(ts, c, color='red')
plt.plot(ts, l, color='blue')
plt.show()

# %%
vce1=[0.1,0.3,0.5,0.6,0.7,0.8,1,3,5,9.68]
vce2=[0.1,0.3,0.5,0.6,0.7,0.8,1,3,5,7.09]
vce3=[0.1,0.3,0.5,0.6,0.7,0.8,1,3,5,5.24]
ic1=[10.5,14.2,14.5,14.5,14.6,14.7,15,17.7,18.9,23.2]
ic2=[17.5,21.4,25.2,31.1,32.3,33.1,34.6,38.3,43,49.1]
ic3=[43.9,44.3,44.7,44.8,45.2,45.8,46.6,51.3,62.6,67.6]
plt.figure(figsize=(8,6))
plt.ylabel('Ic(mA)')
plt.xlabel('Vce(V)')
plt.grid(True)
plt.plot(vce1, ic1, color='red',label='Ib=50uA')
plt.plot(vce2, ic2, color='blue',label='Ib=100uA')
plt.plot(vce3, ic3, color='yellow',label='Ib=150uA')
plt.legend()
plt.show()

# %%
vce=[0.03,0.04,0.05,0.08,10,11.99]
ic1=[7.41,7.36,7.33,7.28,0.18,0]
plt.figure(figsize=(8,6))
plt.ylabel('Ic(mA)')
plt.xlabel('Vce(V)')
plt.grid(True)
plt.plot(vce, ic1, color='red')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
print(9*36)
# Out:
# 324

# %%
x=np.linspace(1,100,10000)
y=[]
for t in x:
    y.append(e(-0.2*t)*sin(3*t))
xs=np.linspace(1,200,20000)
for t in x:
    y.append(e(-0.2*t)*sin(2*t))
plt.figure(figsize=(8,6))
plt.ylabel('f')
plt.xlabel('t')
plt.grid(True)
plt.plot(xs, y, color='red')
plt.show()
